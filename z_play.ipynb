# %%
# %%bash
# CN="/Users/ianscrivener/Library/Containers/com.liuliu.draw-things/Data/Documents/Models/custom_controlnet.json"
# M="/Users/ianscrivener/Library/Containers/com.liuliu.draw-things/Data/Documents/Models/custom.json"
# L="/Users/ianscrivener/Library/Containers/com.liuliu.draw-things/Data/Documents/Models/custom_lora.json"
#
# # jq '[.[] | {display_name_original: .name, file: .file, model_family: .version, model_type: "lora", weight: .weight?}]'  $L
#
# jq '[.[] | {display_name_original: .name, file: .file, model_family: .version, model_type: "lora"} + (if .weight then {weight: .weight} else {} end)]' --color-output $L
# Out:
# [
#   {
#     "display_name_original": "⭐️Qwen-Image-4steps-v2.0-bf16",
#     "file": "qwen_image_4steps_v2.0_bf16_lora_f16.ckpt",
#     "model_family": "qwen_image",
#     "model_type": "lora",
#     "weight": {
#       "value": 1,
#       "lower_bound": 1,
#       "upper_bound": 1
#     }
#   },
#   {
#     "display_name_original": "⭐️Qwen-Image-8steps-v2.0-bf16",
#     "file": "qwen_image_8steps_v2.0_bf16_lora_f16.ckpt",
#     "model_family": "qwen_image",
#     "model_type": "lora",
#     "weight": {
#       "value": 1,
#       "lower_bound": 1,
#       "upper_bound": 1
#     }
#   },
#   {
#     "display_name_original": "qwen_image_edit_inpainting",
#     "file": "qwen_image_edit_inpainting_lora_f16.ckpt",
#     "model_family": "qwen_image",
#     "model_type": "lora"
#   },
#   {
#     "display_name_original": "⭐️Qwen-Image-Lightning-4steps-v2.0-bf16",
#     "file": "qwen_image_lightning_4steps_v2.0_bf16_lora_f16.ckpt",
#     "model_family": "qwen_image",
# ...

# %%
# %%bash
# CN="/Users/ianscrivener/Library/Containers/com.liuliu.draw-things/Data/Documents/Models/custom_controlnet.json"
# M="/Users/ianscrivener/Library/Containers/com.liuliu.draw-things/Data/Documents/Models/custom.json"
# L="/Users/ianscrivener/Library/Containers/com.liuliu.draw-things/Data/Documents/Models/custom_lora.json"
#
# jq '[.[] | {display_name_original: .name, file: .file, model_family: .version, model_type: "controlnet", type: .type, preprocessor: .preprocessor, image_encoder_version: .image_encoder_version, image_encoder: .image_encoder}]' --color-output $CN
# Out:
# [
#   {
#     "display_name_original": "PuLID 0.9.1 (FLUX.1 dev)",
#     "file": "pulid_0.9.1_eva02_clip_l14_336_f16.ckpt",
#     "model_family": "flux1",
#     "model_type": "controlnet",
#     "type": "pulid",
#     "preprocessor": "arcface_f16.ckpt",
#     "image_encoder_version": "eva02_l14_336",
#     "image_encoder": "eva02_clip_l14_336_f16.ckpt"
#   }
# ]

# %%
# %%bash
# CN="/Users/ianscrivener/Library/Containers/com.liuliu.draw-things/Data/Documents/Models/custom_controlnet.json"
# M="/Users/ianscrivener/Library/Containers/com.liuliu.draw-things/Data/Documents/Models/custom.json"
# L="/Users/ianscrivener/Library/Containers/com.liuliu.draw-things/Data/Documents/Models/custom_lora.json"
#
# jq '[.[] | {display_name_original: .name, file: .file, model_family: .version, model_type: "model", autoencoder: .autoencoder, clip_encoder: .clip_encoder, text_encoder: .text_encoder}]' --color-output $M
# Out:
# [
#   {
#     "display_name_original": "Jib Mix Flux v10",
#     "file": "jibmixflux_v10analogagain_f16.ckpt",
#     "model_family": "flux1",
#     "model_type": "model",
#     "autoencoder": "flux_1_vae_f16.ckpt",
#     "clip_encoder": "clip_vit_l14_f16.ckpt",
#     "text_encoder": "t5_xxl_encoder_q6p.ckpt"
#   },
#   {
#     "display_name_original": "FLUX.1 Kontext [dev] (5-bit)",
#     "file": "flux_1_kontext_dev_q5p.ckpt",
#     "model_family": "flux1",
#     "model_type": "model",
#     "autoencoder": "flux_1_vae_f16.ckpt",
#     "clip_encoder": "clip_vit_l14_f16.ckpt",
#     "text_encoder": "t5_xxl_encoder_q6p.ckpt"
#   },
#   {
#     "display_name_original": "FLUX.1 Fill [dev] (5-bit)",
#     "file": "flux_1_fill_dev_q5p.ckpt",
#     "model_family": "flux1",
#     "model_type": "model",
#     "autoencoder": "flux_1_vae_f16.ckpt",
#     "clip_encoder": "clip_vit_l14_f16.ckpt",
#     "text_encoder": "t5_xxl_encoder_q6p.ckpt"
#   },
#   {
# ...

# %%
from matplotlib import pyplot as plt
import numpy as np

# Generate 100 random data points along 3 dimensions
x, y, scale = np.random.randn(3, 100)
fig, ax = plt.subplots()

# Map each onto a scatterplot we'll create with Matplotlib
ax.scatter(x=x, y=y, c=scale, s=np.abs(scale)*500)
ax.set(title="Some random data, created with JupyterLab!")
plt.show()

# %%
! uv pip install ipywidgets
# Out:
# Resolved 20 packages in 261ms
# Installed 20 packages in 137ms
#  + asttokens==3.0.0
#  + comm==0.2.3
#  + decorator==5.2.1
#  + executing==2.2.1
#  + ipython==9.6.0
#  + ipython-pygments-lexers==1.1.1
#  + ipywidgets==8.1.8
#  + jedi==0.19.2
#  + jupyterlab-widgets==3.0.16
#  + matplotlib-inline==0.2.1
#  + parso==0.8.5
#  + pexpect==4.9.0
#  + prompt-toolkit==3.0.52
#  + ptyprocess==0.7.0
#  + pure-eval==0.2.3
#  + pygments==2.19.2
#  + stack-data==0.6.3
#  + traitlets==5.14.3
#  + wcwidth==0.2.14
#  + widgetsnbextension==4.0.15
